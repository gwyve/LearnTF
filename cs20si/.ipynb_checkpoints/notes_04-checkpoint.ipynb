# %% [markdown]
# 这个是写的例子是NLP的，对NLP，目前我还是不是很熟，不过，这个也可以算是一种入门吧
#
# https://github.com/chiphuyen/tf-stanford-tutorials/blob/master/examples/04_word2vec_visualize.py

# %%
# 这里我按照相关信息，我把processed_data的相关位置进行了修改
import os

import numpy as np
from tensorflow.contrib.tensorboard.plugins import projector
import tensorflow as tf

from process_data import process_data


VOCAB_SIZE = 50000
BATCH_SIZE = 128
EMBED_SIZE = 128 # dimension of the word embedding vectors
SKIP_WINDOW = 1 # the context window
NUM_SAMPLED = 64    # Number of negative examples to sample.
LEARNING_RATE = 1.0
NUM_TRAIN_STEPS = 100000
WEIGHTS_FLD = 'processed/'
SKIP_STEP = 2000

    
class SkipGramModel:
    def __init__(self, vocab_size, embed_size, batch_size, num_sampled, learning_rate):
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.batch_size = batch_size
        self.batch_size = batch_size
        self.num_sampled = num_sampled
        self.lr = learning_rate
        self.global_step = tf.Variable(0,dtype=tf.int32,trainable=False,name="global_step")
        
        
    def _create_placeholders(self):
        # 定义占位符
        with tf.name_scope("data"):
            self.center_words = tf.placeholder(tf.int32, shape=[self.batch_size], name='center_words')
            self.target_words = tf.placeholder(tf.int32, shape=[self.batch_size, 1], name='target_words')

    def _create_embedding(self):
        # 创建定义 存词汇的表
        # 可以选择gpu还是cpu
        with tf.device('/cpu:0'):
            with tf.name_scope("embed"):
                self.embed_matrix = tf.Variable(tf.random_uniform([self.vocab_size, 
                                                                    self.embed_size], -1.0, 1.0), 
                                                                    name='embed_matrix')
                
    def _create_loss(self):
        
        with tf.device('/cpu:0'):
            with tf.name_scope("loss"):
                # 这个我所理解的就是根据一个词的one-hot对应出另一个不是one-hot的向量
                embed = tf.nn.embedding_lookup(self.embed_matrix, self.center_words, name='embed')

                # 定义一个损失
                nce_weight = tf.Variable(tf.truncated_normal([self.vocab_size, self.embed_size],
                                                            stddev=1.0 / (self.embed_size ** 0.5)), 
                                                            name='nce_weight')
                nce_bias = tf.Variable(tf.zeros([VOCAB_SIZE]), name='nce_bias')

                
                self.loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weight, 
                                                    biases=nce_bias, 
                                                    labels=self.target_words, 
                                                    inputs=embed, 
                                                    num_sampled=self.num_sampled, 
                                                    num_classes=self.vocab_size), name='loss')
    def _create_optimizer(self):
        # 定义一个最佳器
        with tf.device('/cpu:0'):
            self.optimizer = tf.train.GradientDescentOptimizer(self.lr).minimize(self.loss, 
                                                              global_step=self.global_step)

    def _create_summaries(self):
        # 定义一个用于记录的东西
        with tf.name_scope("summaries"):
            tf.summary.scalar("loss", self.loss)
            tf.summary.histogram("histogram_loss", self.loss)
            # because you have several summaries, we should merge them all into one op to make it easier to manage
            self.summary_op = tf.summary.merge_all()
        
        
    def build_graph(self):
        # 构建模型
        self._create_placeholders()
        self._create_embedding()
        self._create_loss()
        self._create_optimizer()
        self._create_summaries()

def train_model(model, batch_gen, num_train_steps, weights_fld):
    saver = tf.train.Saver() # defaults to saving all variables - in this case embed_matrix, nce_weight, nce_bias
    # 保存用的工具
    
    initial_step = 0
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        ckpt = tf.train.get_checkpoint_state(os.path.dirname('checkpoints/checkpoint'))
        # 运行的时候，需要创建checkpoints文件夹
        # if that checkpoint exists, restore from checkpoint
        if ckpt and ckpt.model_checkpoint_path:
            saver.restore(sess, ckpt.model_checkpoint_path)
            # 这个就是发现有没有checkpoint，如果有checkpoing的话，就把最新的数据加进去
            
        total_loss = 0.0 # we use this to calculate late average loss in the last SKIP_STEP steps
        writer = tf.summary.FileWriter('./improved_graph/lr' + str(LEARNING_RATE), sess.graph)
        initial_step = model.global_step.eval()
        for index in xrange(initial_step, initial_step + num_train_steps):
            centers, targets = batch_gen.next()
            feed_dict={model.center_words: centers, model.target_words: targets}
            loss_batch, _, summary = sess.run([model.loss, model.optimizer, model.summary_op], 
                                              feed_dict=feed_dict)
            writer.add_summary(summary, global_step=index)
            total_loss += loss_batch
            if (index + 1) % SKIP_STEP == 0:
                print('Average loss at step {}: {:5.1f}'.format(index, total_loss / SKIP_STEP))
                total_loss = 0.0
                saver.save(sess, 'checkpoints/skip-gram', index)
        
        


model = SkipGramModel(VOCAB_SIZE, EMBED_SIZE, BATCH_SIZE, NUM_SAMPLED, LEARNING_RATE) # 创建一个对象
model.build_graph()
batch_gen = process_data(VOCAB_SIZE, BATCH_SIZE, SKIP_WINDOW)
train_model(model, batch_gen, NUM_TRAIN_STEPS, WEIGHTS_FLD)
# Out:
# Dataset ready
# Average loss at step 1999: 116.1
# Average loss at step 3999:  54.9
# Average loss at step 5999:  36.5
# Average loss at step 7999:  25.7
# Average loss at step 9999:  19.5
# Average loss at step 11999:  15.0
# Average loss at step 13999:  11.7
# Average loss at step 15999:   9.8
# Average loss at step 17999:   8.3
# Average loss at step 19999:   7.4
# Average loss at step 21999:   7.3
# Average loss at step 23999:   6.8
# Average loss at step 25999:   6.5
# Average loss at step 27999:   6.2
# Average loss at step 29999:   5.7
# Average loss at step 31999:   5.8
# Average loss at step 33999:   5.6
# Average loss at step 35999:   5.4
# Average loss at step 37999:   5.3
# Average loss at step 39999:   5.3
# Average loss at step 41999:   5.1
# Average loss at step 43999:   8.9
# Average loss at step 45999:   5.4
# Average loss at step 47999:   5.3
# Average loss at step 49999:  10.0
# Average loss at step 51999:   5.2
# Average loss at step 53999:   5.0
# Average loss at step 55999:   5.0
# Average loss at step 57999:   4.9
# Average loss at step 59999:   4.8
# Average loss at step 61999:   4.8
# Average loss at step 63999:   5.7
# Average loss at step 65999:   4.8
# Average loss at step 67999:   4.7
# Average loss at step 69999:   4.5
# Average loss at step 71999:   4.8
# Average loss at step 73999:   5.2
# Average loss at step 75999:   4.7
# Average loss at step 77999:   4.6
# Average loss at step 79999:   4.6
# Average loss at step 81999:   4.6
# Average loss at step 83999:   4.9
# Average loss at step 85999:   4.6
# Average loss at step 87999:   5.4
# Average loss at step 89999:   4.6
# Average loss at step 91999:   4.6
# Average loss at step 93999:   4.5
# Average loss at step 95999:   5.5
# Average loss at step 97999:   4.6
# Average loss at step 99999:   4.5
